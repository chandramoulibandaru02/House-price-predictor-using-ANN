# %%
import pandas as pd

# %% [markdown]
# Here we got 2 data sets they are one is Testig and other is Training data

# %%
df1=pd.read_csv('/content/test.csv')

# %%
df1.isnull().sum()
# Out:
# POSTED_BY             0
# UNDER_CONSTRUCTION    0
# RERA                  0
# BHK_NO.               0
# BHK_OR_RK             0
# SQUARE_FT             0
# READY_TO_MOVE         0
# RESALE                0
# ADDRESS               0
# LONGITUDE             0
# LATITUDE              0
# dtype: int64

# %%
df2=pd.read_csv('/content/train.csv')

# %%
df2.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        1       BHK   545.171340
# 1    Dealer                   1     1        2       BHK   800.000000
# 2    Dealer                   0     0        2       BHK  1257.096513
# 3    Dealer                   0     0        3       BHK  1400.329489
# 4     Owner                   0     0        1       BHK   430.477830
#
#    READY_TO_MOVE  RESALE             ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Kamrej,Surat  21.262000  73.047700
# 1              0       0     Panvel,Lalitpur  18.966114  73.148278
# 2              1       1    New Town,Kolkata  22.592200  88.484911
# 3              1       1  Kalwar Road,Jaipur  26.988300  75.584600
# 4              1       1   Mai Mandir,Nadiad  22.700000  72.870000
#
#    TARGET(PRICE_IN_LACS)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# ...

# %%
df=df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0    Dealer                   0     0        3       BHK  1659.828422
# 1    Dealer                   0     1        1       BHK   672.020980
# 2    Dealer                   0     0        3       BHK   911.023383
# 3     Owner                   0     0        2       BHK  1000.000000
# 4    Dealer                   0     0        1       BHK  1442.169022
#
#    READY_TO_MOVE  RESALE                   ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1  Suraksha Nagar,Bangalore  20.098413  79.107860
# 1              1       1    Kalyan (West),Lalitpur  19.245347  73.124577
# 2              1       1   Chembur (East),Lalitpur  19.058710  72.899690
# 3              1       1     Trimurti Nagar,Nagpur  21.111835  79.038732
# 4              1       1       Thane West,Lalitpur  19.180000  72.963330
#
#    TARGET(PRICE_IN_LACS)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98171 entries, 0 to 98170
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              98171 non-null  object
#  1   UNDER_CONSTRUCTION     98171 non-null  int64
#  2   RERA                   98171 non-null  int64
#  3   BHK_NO.                98171 non-null  int64
#  4   BHK_OR_RK              98171 non-null  object
#  5   SQUARE_FT              98171 non-null  float64
#  6   READY_TO_MOVE          98171 non-null  int64
#  7   RESALE                 98171 non-null  int64
#  8   ADDRESS                98171 non-null  object
#  9   LONGITUDE              98171 non-null  float64
#  10  LATITUDE               98171 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 9.0+ MB

# %%
col=df.columns
print(col)
print()
print()

print("*"*100)
print()
print()
for i in col:
  print(i,": ",df[i].unique())
  print("*"*100)
  print()
  print()
  print(df[i].value_counts())
  print("*"*100)
# Out:
# Index(['POSTED_BY', 'UNDER_CONSTRUCTION', 'RERA', 'BHK_NO.', 'BHK_OR_RK',
#        'SQUARE_FT', 'READY_TO_MOVE', 'RESALE', 'ADDRESS', 'LONGITUDE',
#        'LATITUDE', 'TARGET(PRICE_IN_LACS)'],
#       dtype='object')
#
#
# ****************************************************************************************************
#
#
# POSTED_BY :  ['Dealer' 'Owner' 'Builder']
# ****************************************************************************************************
#
#
# POSTED_BY
# Dealer     60728
# Owner      35458
# Builder     1985
# Name: count, dtype: int64
# ****************************************************************************************************
# UNDER_CONSTRUCTION :  [0 1]
# ****************************************************************************************************
#
#
# UNDER_CONSTRUCTION
# 0    80744
# 1    17427
# Name: count, dtype: int64
# ****************************************************************************************************
# ...

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        98171.000000  98171.000000  98171.000000  9.817100e+04
# mean             0.177517      0.316947      2.389423  7.874292e+03
# std              0.382107      0.465289      0.868954  1.050427e+06
# min              0.000000      0.000000      1.000000  1.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000277e+02
# 50%              0.000000      0.000000      2.000000  1.175007e+03
# 75%              0.000000      1.000000      3.000000  1.550388e+03
# max              1.000000      1.000000     31.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   98171.000000  98171.000000  98171.000000  98171.000000
# mean        0.822483      0.932322     21.291708     76.894881
# std         0.382107      0.251194      6.186898     10.240142
# min         0.000000      0.000000    -38.391261   -121.761248
# ...

# %%
df.isnull().sum()
# Out:
# POSTED_BY                    0
# UNDER_CONSTRUCTION           0
# RERA                         0
# BHK_NO.                      0
# BHK_OR_RK                    0
# SQUARE_FT                    0
# READY_TO_MOVE                0
# RESALE                       0
# ADDRESS                      0
# LONGITUDE                    0
# LATITUDE                     0
# TARGET(PRICE_IN_LACS)    68720
# dtype: int64

# %%
df['TARGET(PRICE_IN_LACS)']=df['TARGET(PRICE_IN_LACS)'].fillna(df['TARGET(PRICE_IN_LACS)'].median())

# %%
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        98171.000000  98171.000000  98171.000000  9.817100e+04
# mean             0.177517      0.316947      2.389423  7.874292e+03
# std              0.382107      0.465289      0.868954  1.050427e+06
# min              0.000000      0.000000      1.000000  1.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000277e+02
# 50%              0.000000      0.000000      2.000000  1.175007e+03
# 75%              0.000000      1.000000      3.000000  1.550388e+03
# max              1.000000      1.000000     31.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   98171.000000  98171.000000  98171.000000  98171.000000
# mean        0.822483      0.932322     21.291708     76.894881
# std         0.382107      0.251194      6.186898     10.240142
# min         0.000000      0.000000    -38.391261   -121.761248
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98171 entries, 0 to 98170
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              98171 non-null  object
#  1   UNDER_CONSTRUCTION     98171 non-null  int64
#  2   RERA                   98171 non-null  int64
#  3   BHK_NO.                98171 non-null  int64
#  4   BHK_OR_RK              98171 non-null  object
#  5   SQUARE_FT              98171 non-null  float64
#  6   READY_TO_MOVE          98171 non-null  int64
#  7   RESALE                 98171 non-null  int64
#  8   ADDRESS                98171 non-null  object
#  9   LONGITUDE              98171 non-null  float64
#  10  LATITUDE               98171 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  98171 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 9.0+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
s=LabelEncoder()

# %%
df['POSTED_BY']=s.fit_transform(df['POSTED_BY'])

# %%
s=df['POSTED_BY'].value_counts()

# %%
labels=['Owner','Dealer','Builder']
col=['lightpink','lightgreen','white']
plt.pie(s,labels=labels,colors=col,autopct='%1.1f%%', startangle=0)
plt.show()

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0          1                   0     0        3       BHK  1659.828422
# 1          1                   0     1        1       BHK   672.020980
# 2          1                   0     0        3       BHK   911.023383
# 3          2                   0     0        2       BHK  1000.000000
# 4          1                   0     0        1       BHK  1442.169022
#
#    READY_TO_MOVE  RESALE                   ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1  Suraksha Nagar,Bangalore  20.098413  79.107860
# 1              1       1    Kalyan (West),Lalitpur  19.245347  73.124577
# 2              1       1   Chembur (East),Lalitpur  19.058710  72.899690
# 3              1       1     Trimurti Nagar,Nagpur  21.111835  79.038732
# 4              1       1       Thane West,Lalitpur  19.180000  72.963330
#
#    TARGET(PRICE_IN_LACS)
# 0                   62.0
# 1                   62.0
# ...

# %%
col=df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98171 entries, 0 to 98170
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              98171 non-null  int64
#  1   UNDER_CONSTRUCTION     98171 non-null  int64
#  2   RERA                   98171 non-null  int64
#  3   BHK_NO.                98171 non-null  int64
#  4   BHK_OR_RK              98171 non-null  object
#  5   SQUARE_FT              98171 non-null  float64
#  6   READY_TO_MOVE          98171 non-null  int64
#  7   RESALE                 98171 non-null  int64
#  8   ADDRESS                98171 non-null  object
#  9   LONGITUDE              98171 non-null  float64
#  10  LATITUDE               98171 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  98171 non-null  float64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 9.0+ MB

# %%
df['BHK_OR_RK'].unique()
# Out:
# array(['BHK', 'RK'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
s=LabelEncoder()
df['BHK_OR_RK']=s.fit_transform(df['BHK_OR_RK'])

# %%
df['BHK_OR_RK'].value_counts()
# Out:
# BHK_OR_RK
# 0    98089
# 1       82
# Name: count, dtype: int64

# %%
plt.pie(df['BHK_OR_RK'].value_counts(),labels=['BHK','RK'],colors=['red','black'],autopct='%1.1f%%',startangle=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98171 entries, 0 to 98170
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              98171 non-null  int64
#  1   UNDER_CONSTRUCTION     98171 non-null  int64
#  2   RERA                   98171 non-null  int64
#  3   BHK_NO.                98171 non-null  int64
#  4   BHK_OR_RK              98171 non-null  int64
#  5   SQUARE_FT              98171 non-null  float64
#  6   READY_TO_MOVE          98171 non-null  int64
#  7   RESALE                 98171 non-null  int64
#  8   ADDRESS                98171 non-null  object
#  9   LONGITUDE              98171 non-null  float64
#  10  LATITUDE               98171 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  98171 non-null  float64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 9.0+ MB

# %%
df.head()
# Out:
#    POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK    SQUARE_FT  \
# 0          1                   0     0        3          0  1659.828422
# 1          1                   0     1        1          0   672.020980
# 2          1                   0     0        3          0   911.023383
# 3          2                   0     0        2          0  1000.000000
# 4          1                   0     0        1          0  1442.169022
#
#    READY_TO_MOVE  RESALE                   ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1  Suraksha Nagar,Bangalore  20.098413  79.107860
# 1              1       1    Kalyan (West),Lalitpur  19.245347  73.124577
# 2              1       1   Chembur (East),Lalitpur  19.058710  72.899690
# 3              1       1     Trimurti Nagar,Nagpur  21.111835  79.038732
# 4              1       1       Thane West,Lalitpur  19.180000  72.963330
#
#    TARGET(PRICE_IN_LACS)
# 0                   62.0
# 1                   62.0
# ...

# %%
x=df.drop(columns=['ADDRESS','LONGITUDE','LATITUDE','TARGET(PRICE_IN_LACS)'])

# %%
y=df['TARGET(PRICE_IN_LACS)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("x_train shape: ",x_train.shape)
print("x_test shape: ",x_test.shape)
print("y_train shape: ",y_train.shape)
print("y_test shape: ",y_test.shape)
# Out:
# x_train shape:  (78536, 8)
# x_test shape:  (19635, 8)
# y_train shape:  (78536,)
# y_test shape:  (19635,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential([
    Dense(8,activation='relu'),
    Dense(16,activation='relu'),
    Dense(5,activation='relu'),
    Dense(1,activation='linear')
])

# %%
model.compile(
    optimizer='adam',
    metrics=['mae'],
    loss='mean_squared_error'
)

# %%
history=model.fit(x_train,y_train,epochs=2,validation_split=0.33,batch_size=32)
# Out:
# Epoch 1/2
# 1645/1645 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1212724.2500 - mae: 48.1492 - val_loss: 20134596.0000 - val_mae: 86.1175
# Epoch 2/2
# 1645/1645 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 10953749.0000 - mae: 75.0598 - val_loss: 404387008.0000 - val_mae: 168.4369

# %%
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['mae'],label='val_loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['mae'],label='mae')
plt.plot(history.history['val_mae'],label='val_mae')
plt.legend()
plt.show()

# %%
y_pred=model.predict(x_test)
# Out:
# 614/614 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
y_pred
# Out:
# array([[81.006195],
#        [69.415665],
#        [86.29031 ],
#        ...,
#        [79.293785],
#        [62.560173],
#        [93.054634]], dtype=float32)

# %%
from sklearn.metrics import r2_score

# %%
sc=r2_score(y_test,y_pred)

# %%
sc
# Out:
# -2.485916818707607

# %%
import numpy as np
input=np.array([[0,2,1,1,3,0,1090,1]])
(input.reshape(-1,1))
# Out:
# array([[   0],
#        [   2],
#        [   1],
#        [   1],
#        [   3],
#        [   0],
#        [1090],
#        [   1]])

# %%
ypred=model.predict(input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step

# %%
y_pred[0][0]
# Out:
# np.float32(81.006195)
